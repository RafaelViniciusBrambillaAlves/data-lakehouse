# %%
from processing.spark.utils.spark_session import create_spark_session

# %%
spark = create_spark_session("explore-gold")
# Out:
# Warning: Ignoring non-Spark config property: hive.metastore.uris
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/13 19:07:15 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
gold_ratings_over_time = spark.read.format("parquet").load("s3a://lakehouse/gold.db/gold_ratings_over_time")
# Out:
# 26/04/13 19:07:16 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties

# %%
gold_ratings_over_time.limit(10).show(truncate = False)
# Out:
# +----------+-------------+------------------+-------------------+
# |event_date|total_ratings|avg_rating        |pct_positive       |
# +----------+-------------+------------------+-------------------+
# |2019-05-21|1000         |3.601             |0.5                |
# |1997-09-28|96           |3.1875            |0.4375             |
# |2014-10-17|76           |3.5197368421052633|0.4342105263157895 |
# |2004-08-11|199          |3.4974874371859297|0.41708542713567837|
# |1998-07-09|11           |3.090909090909091 |0.5454545454545454 |
# |2007-07-23|153          |3.7058823529411766|0.5816993464052288 |
# |2013-07-01|264          |3.507575757575758 |0.42424242424242425|
# |2006-06-15|101          |3.0792079207920793|0.24752475247524752|
# |2006-04-23|135          |3.522222222222222 |0.4222222222222222 |
# |2008-03-17|258          |3.887596899224806 |0.6627906976744186 |
# +----------+-------------+------------------+-------------------+

# %%
gold_top_movies = spark.read.format("parquet").load("s3a://lakehouse/gold.db/gold_top_movies")

# %%
gold_top_movies.limit(10).show(truncate = False)
# Out:
# +--------+----------------------------------------------+------------+-------------+------------------+
# |movie_id|title                                         |release_year|total_ratings|avg_rating        |
# +--------+----------------------------------------------+------------+-------------+------------------+
# |170705  |Band of Brothers                              |2001        |1444         |4.385734072022161 |
# |171011  |Planet Earth II                               |2016        |803          |4.376089663760896 |
# |26073   |Human Condition III, The (Ningen no joken III)|1961        |51           |4.372549019607843 |
# |159817  |Planet Earth                                  |2006        |1143         |4.3718285214348205|
# |318     |Shawshank Redemption, The                     |1994        |10066        |4.351629246969998 |
# |172591  |The Godfather Trilogy: 1972-1990              |1992        |293          |4.32764505119454  |
# |185135  |Sherlock - A Study in Pink                    |2010        |276          |4.326086956521739 |
# |1203    |12 Angry Men                                  |1957        |3600         |4.306388888888889 |
# |174053  |Black Mirror: White Christmas                 |2014        |602          |4.304817275747508 |
# |6896    |Shoah                                         |1985        |84           |4.303571428571429 |
# +--------+----------------------------------------------+------------+-------------+------------------+

# %%
gold_worst_movies = spark.read.format("parquet").load("s3a://lakehouse/gold.db/gold_worst_movies")

# %%
gold_worst_movies.limit(10).show(truncate = False)
# Out:
# +--------+-----------------------------+------------+-------------+------------------+
# |movie_id|title                        |release_year|total_ratings|avg_rating        |
# +--------+-----------------------------+------------+-------------+------------------+
# |8859    |SuperBabies: Baby Geniuses 2 |2004        |51           |0.7450980392156863|
# |4775    |Glitter                      |2001        |58           |1.0172413793103448|
# |67867   |Dragonball Evolution         |2009        |199          |1.1758793969849246|
# |31698   |Son of the Mask              |2005        |208          |1.1875            |
# |61348   |Disaster Movie               |2008        |174          |1.2183908045977012|
# |6872    |House of the Dead, The       |2003        |68           |1.2794117647058822|
# |135216  |The Star Wars Holiday Special|1978        |123          |1.3495934959349594|
# |6587    |Gigli                        |2003        |111          |1.382882882882883 |
# |26157   |Manos: The Hands of Fate     |1966        |70           |1.3928571428571428|
# |50798   |Epic Movie                   |2007        |327          |1.4250764525993884|
# +--------+-----------------------------+------------+-------------+------------------+

# %%
spark.stop()
